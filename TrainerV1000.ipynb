# %%
from Pointcloud.Modules.Manager import Manager

from pathlib import Path

# EXAMPLE_OBJ_FILE = "common-3d-test-models-master/stanford-bunny.obj"
# EXAMPLE_OBJ_FILE = "common-3d-test-models-master/fandisk.obj"
# EXAMPLE_OBJ_FILE = "common-3d-test-models-master/beetle.obj"
# EXAMPLE_OBJ_FILE = "untitled.obj"
# Out:
# c:\Users\ruben\miniconda3\envs\PCDenoiser\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: '[WinError 127] The specified procedure could not be found'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# c:\Users\ruben\miniconda3\envs\PCDenoiser\lib\site-packages\torchaudio\backend\utils.py:62: UserWarning: No audio backend is available.
#   warnings.warn("No audio backend is available.")

# %%
manager = Manager()
# Out:
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Model size: 2.2754478454589844 MB
# Train Dataset size: 150.74620056152344 MB

# %%
manager.train()
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | layer0    | EdgeConv   | 1.2 K
# 1 | layer1    | EdgeConv   | 16.6 K
# 2 | layer2    | EdgeConv   | 66.0 K
# 3 | layer3    | Sequential | 230 K
# 4 | layer4    | Sequential | 262 K
# 5 | layer5    | Sequential | 16.6 K
# 6 | lastLayer | Linear     | 195
# -----------------------------------------
# 593 K     Trainable params
# 0         Non-trainable params
# 593 K     Total params
# 2.376     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Starting to train!
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Training is done.
# FIT Profiler Report
# Profile stats for: records
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                           ProfilerStep*         8.59%      51.643ms        99.89%     600.667ms      30.033ms      42.459ms         7.06%     600.908ms      30.045ms            20
# [pl][profile][Strategy]SingleDeviceStrategy.validati...        13.58%      81.648ms        77.13%     463.842ms      23.192ms      63.461ms        10.55%     464.173ms      23.209ms            20
# [pl][module]torch_geometric.nn.conv.edge_conv.EdgeCo...         1.88%      11.314ms        12.78%      76.857ms       3.843ms       7.632ms         1.27%      74.815ms       3.741ms            20
#                                            aten::linear         1.93%      11.618ms        12.65%      76.051ms     271.611us       7.233ms         1.20%      92.093ms     328.904us           280
# [pl][module]torch_geometric.nn.conv.edge_conv.EdgeCo...         2.33%      14.019ms        10.98%      66.040ms       3.302ms       9.559ms         1.59%      66.620ms       3.331ms            20
#                                 aten::cosine_similarity         2.40%      14.433ms         9.79%      58.871ms     735.888us       9.638ms         1.60%      59.752ms     746.900us            80
# [pl][module]torch_geometric.nn.conv.edge_conv.EdgeCo...         1.37%       8.229ms         8.19%      49.278ms       2.464ms       2.601ms         0.43%      52.935ms       2.647ms            20
#                                             aten::zeros         6.94%      41.748ms         7.77%      46.736ms      44.091us      26.893ms         4.47%      53.439ms      50.414us          1060
#                                                aten::to         1.43%       8.574ms         6.43%      38.689ms      55.270us      10.661ms         1.77%      45.212ms      64.589us           700
# [pl][profile][Strategy]SingleDeviceStrategy.batch_to...         1.07%       6.421ms         5.33%      32.054ms       1.603ms       5.410ms         0.90%      32.303ms       1.615ms            20
# [pl][module]torch.nn.modules.container.Sequential: l...         1.07%       6.447ms         5.03%      30.224ms       1.511ms       5.400ms         0.90%      30.493ms       1.525ms            20
#                                          aten::_to_copy         2.82%      16.986ms         5.01%      30.115ms      75.287us      12.346ms         2.05%      34.551ms      86.377us           400
# [pl][module]torch_geometric.nn.aggr.basic.MeanAggreg...         2.21%      13.269ms         4.45%      26.749ms       1.337ms      10.871ms         1.81%      27.108ms       1.355ms            20
# [pl][module]torch.nn.modules.container.Sequential: l...         0.89%       5.335ms         4.37%      26.308ms       1.315ms       4.154ms         0.69%      26.453ms       1.323ms            20
#                                        aten::batch_norm         0.40%       2.398ms         4.31%      25.906ms     215.883us       1.505ms         0.25%      26.896ms     224.133us           120
# [pl][module]torch.nn.modules.container.Sequential: l...         0.78%       4.669ms         4.15%      24.948ms       1.247ms       3.840ms         0.64%      25.189ms       1.259ms            20
# [pl][module]torch.nn.modules.container.Sequential: l...         0.79%       4.751ms         4.10%      24.657ms       1.233ms       3.647ms         0.61%      24.769ms       1.238ms            20
#                            aten::_batch_norm_impl_index         0.71%       4.254ms         3.91%      23.508ms     195.900us       2.863ms         0.48%      25.391ms     211.592us           120
# [pl][module]torch.nn.modules.container.Sequential: l...         0.72%       4.322ms         3.70%      22.256ms       1.113ms       3.114ms         0.52%      21.038ms       1.052ms            20
# [pl][profile][LightningModule]Patch2NormalModel.tran...         1.25%       7.525ms         3.65%      21.954ms       1.098ms       6.618ms         1.10%      22.233ms       1.112ms            20
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 601.357ms
# Self CUDA time total: 601.713ms

# %%
from Pointcloud.Modules.Visualize import visSample
visSample(manager.train_dl.dataset[0])
# Out:
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(-0.011798…
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 from Pointcloud.Modules.Visualize import visSample
# ----> 2 visSample(manager.train_dl.dataset[0])
#
# File c:\Users\ruben\Documents\TUDelft\IN5000FinalProject\GCN-Pointcloud-Denoiser\Pointcloud\Modules\Visualize.py:164, in visSample(data)
#     162 plot.add_lines(_pos[_edge_index[0]].numpy(), _pos[_edge_index[1]].numpy())
#     163 plot.add_lines(_pos.numpy(), (_pos + _n).numpy())
# --> 164 plot.add_lines(_pos[0].numpy(), (_pos[0] + _y).numpy())
#
# File c:\Users\ruben\miniconda3\envs\PCDenoiser\lib\site-packages\meshplot\Viewer.py:298, in Viewer.add_lines(self, beginning, ending, shading, obj)
#     294         ending = np.append(
#     295             ending, np.zeros([ending.shape[0], 1]), 1)
#     297 sh = self.__get_shading(shading)
# --> 298 lines = np.hstack([beginning, ending])
#     299 lines = lines.reshape((-1, 3))
#     300 return self.__add_line_geometry(lines, sh, obj)
#
# File c:\Users\ruben\miniconda3\envs\PCDenoiser\lib\site-packages\numpy\core\shape_base.py:357, in hstack(tup, dtype, casting)
#     355 # As a special case, dimension 0 of 1-dimensional arrays is "horizontal"
#     356 if arrs and arrs[0].ndim == 1:
# --> 357     return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#     358 else:
#     359     return _nx.concatenate(arrs, 1, dtype=dtype, casting=casting)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 1 dimension(s) and the array at index 1 has 2 dimension(s)

# %%
manager.validate()
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#      Validate metric           DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#       val_cos_loss          1.0123810768127441
#    val_custom_cos_loss      0.3334248960018158
#    val_custom_val_loss      0.1955922394990921
#       val_val_loss           0.564909040927887
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# VALIDATE Profiler Report
# Profile stats for: records
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                           ProfilerStep*         7.31%      48.639ms        99.87%     664.885ms      33.244ms      41.515ms         6.23%     665.108ms      33.255ms            20
# [pl][profile][Strategy]SingleDeviceStrategy.validati...        11.58%      77.125ms        71.89%     478.605ms      23.930ms      59.882ms         8.99%     478.907ms      23.945ms            20
#                                            aten::linear         2.21%      14.736ms        13.93%      92.770ms     331.321us       8.992ms         1.35%      98.690ms     352.464us           280
#                             aten::cosine_embedding_loss         1.73%      11.531ms         9.19%      61.206ms       1.530ms       9.726ms         1.46%      61.714ms       1.543ms            40
#                 [pl][profile][_EvaluationLoop].val_next         0.65%       4.342ms         9.01%      59.959ms       2.998ms       3.963ms         0.59%      60.437ms       3.022ms            20
# [pl][module]torch_geometric.nn.conv.edge_conv.EdgeCo...         1.57%      10.431ms         8.90%      59.253ms       2.963ms       8.213ms         1.23%      60.135ms       3.007ms            20
# enumerate(DataLoader)#_MultiProcessingDataLoaderIter...         7.93%      52.794ms         8.16%      54.342ms       2.717ms      42.544ms         6.39%      54.736ms       2.737ms            20
#                                             aten::zeros         7.45%      49.581ms         8.16%      54.330ms      51.255us      30.019ms         4.51%      60.099ms      56.697us          1060
# [pl][module]torch_geometric.nn.conv.edge_conv.EdgeCo...         1.33%       8.835ms         7.92%      52.730ms       2.636ms       5.486ms         0.82%      55.149ms       2.757ms            20
#                                                aten::to         1.74%      11.613ms         7.12%      47.413ms      60.786us      13.377ms         2.01%      53.588ms      68.703us           780
# [pl][module]torch_geometric.nn.conv.edge_conv.EdgeCo...         1.27%       8.487ms         7.09%      47.204ms       2.360ms       3.110ms         0.47%      52.269ms       2.613ms            20
#                                 aten::cosine_similarity         1.32%       8.821ms         5.52%      36.724ms     918.100us       5.764ms         0.87%      36.734ms     918.350us            40
#                                          aten::_to_copy         2.91%      19.384ms         5.38%      35.800ms      89.500us      14.405ms         2.16%      40.211ms     100.528us           400
#                                        aten::batch_norm         0.32%       2.119ms         5.05%      33.590ms     279.917us       1.636ms         0.25%      34.345ms     286.208us           120
# [pl][profile][Strategy]SingleDeviceStrategy.batch_to...         0.78%       5.215ms         4.76%      31.718ms       1.586ms       4.396ms         0.66%      31.896ms       1.595ms            20
#                            aten::_batch_norm_impl_index         0.96%       6.366ms         4.73%      31.471ms     262.258us       4.688ms         0.70%      32.709ms     272.575us           120
# [pl][module]torch.nn.modules.container.Sequential: l...         0.86%       5.693ms         4.60%      30.618ms       1.531ms       4.545ms         0.68%      30.881ms       1.544ms            20
# [pl][module]torch.nn.modules.container.Sequential: l...         0.86%       5.699ms         4.58%      30.461ms       1.523ms       4.634ms         0.70%      30.731ms       1.537ms            20
# [pl][module]torch.nn.modules.container.Sequential: l...         0.82%       5.474ms         4.51%      30.017ms       1.501ms       3.253ms         0.49%      25.359ms       1.268ms            20
# [pl][module]torch.nn.modules.container.Sequential: l...         0.87%       5.782ms         4.51%      30.001ms       1.500ms       4.502ms         0.68%      30.104ms       1.505ms            20
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 665.755ms
# Self CUDA time total: 666.056ms

# %%
manager.test(from_checkpoint=str(Path(manager.trainer.logger.log_dir) / "checkpoints/sample-mnist-epoch27-val_val_loss0.08.ckpt"))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 manager.test(from_checkpoint=str(Path(manager.trainer.logger.log_dir) / "checkpoints/sample-mnist-epoch27-val_val_loss0.08.ckpt"))
#
# File c:\Users\ruben\Documents\TUDelft\IN5000FinalProject\GCN-Pointcloud-Denoiser\Pointcloud\Modules\Manager.py:77, in Manager.test(self, from_checkpoint)
#      76 def test(self, from_checkpoint: str=None):
# ---> 77     self.assertCheckpointFile(from_checkpoint)
#      78     self.trainer.test(self.model, self.test_dl, ckpt_path=from_checkpoint)
#
# File c:\Users\ruben\Documents\TUDelft\IN5000FinalProject\GCN-Pointcloud-Denoiser\Pointcloud\Modules\Manager.py:66, in Manager.assertCheckpointFile(self, checkpoint)
#      64 if checkpoint is not None:
#      65     path = Path(checkpoint)
# ---> 66     assert path.exists() and path.suffix == ".ckpt", f"Exists: {path.exists()}\nsuffix: {path.suffix}\nFull path: {str(path)}"
#
# AssertionError: Exists: False
# suffix: .ckpt
# Full path: tb_logs\testmodel\version_55\checkpoints\sample-mnist-epoch27-val_val_loss0.08.ckpt

# %%
# obj = manager.train_dl.__iter__()
import torch

obj = torch.tensor([[10, 10], [20, 30]])
for i, k in enumerate(dir(obj)):
    if not k.startswith("__"):
        try:
            print(i, k, getattr(obj, k))
        except:
            print(f"ERROR: {i} {k}")
# Out:
# 0 H tensor([[10, 20],
#         [10, 30]])
# 1 T tensor([[10, 20],
#         [10, 30]])
# 96 _addmm_activation <built-in method _addmm_activation of Tensor object at 0x000002B4AE1E3D60>
# 97 _autocast_to_full_precision <built-in method _autocast_to_full_precision of Tensor object at 0x000002B4AE1E3D60>
# 98 _autocast_to_reduced_precision <built-in method _autocast_to_reduced_precision of Tensor object at 0x000002B4AE1E3D60>
# 99 _backward_hooks None
# 100 _base None
# 101 _cdata 2975132548816
# 102 _coalesced_ <built-in method _coalesced_ of Tensor object at 0x000002B4AE1E3D60>
# 103 _conj <built-in method _conj of Tensor object at 0x000002B4AE1E3D60>
# 104 _conj_physical <built-in method _conj_physical of Tensor object at 0x000002B4AE1E3D60>
# 105 _dimI <built-in method _dimI of Tensor object at 0x000002B4AE1E3D60>
# 106 _dimV <built-in method _dimV of Tensor object at 0x000002B4AE1E3D60>
# 107 _fix_weakref <built-in method _fix_weakref of Tensor object at 0x000002B4AE1E3D60>
# 108 _grad None
# 109 _grad_fn None
# 110 _indices <built-in method _indices of Tensor object at 0x000002B4AE1E3D60>
# 111 _is_view <built-in method _is_view of Tensor object at 0x000002B4AE1E3D60>
# 112 _is_zerotensor <built-in method _is_zerotensor of Tensor object at 0x000002B4AE1E3D60>
# 113 _make_subclass <built-in method _make_subclass of torch._C._TensorMeta object at 0x00007FFC3CD8E960>
# 114 _make_wrapper_subclass <built-in method _make_wrapper_subclass of torch._C._TensorMeta object at 0x00007FFC3CD8E960>
# 115 _neg_view <built-in method _neg_view of Tensor object at 0x000002B4AE1E3D60>
# 116 _nested_tensor_layer_norm <built-in method _nested_tensor_layer_norm of Tensor object at 0x000002B4AE1E3D60>
# 117 _nnz <built-in method _nnz of Tensor object at 0x000002B4AE1E3D60>
# 118 _python_dispatch False
# 119 _reduce_ex_internal <bound method Tensor._reduce_ex_internal of tensor([[10, 10],
#         [20, 30]])>
# 120 _storage <built-in method _storage of Tensor object at 0x000002B4AE1E3D60>
# 121 _to_dense <built-in method _to_dense of Tensor object at 0x000002B4AE1E3D60>
# 122 _update_names <bound method Tensor._update_names of tensor([[10, 10],
#         [20, 30]])>
# 123 _values <built-in method _values of Tensor object at 0x000002B4AE1E3D60>
# 124 _version 0
# 125 abs <built-in method abs of Tensor object at 0x000002B4AE1E3D60>
# 126 abs_ <built-in method abs_ of Tensor object at 0x000002B4AE1E3D60>
# 127 absolute <built-in method absolute of Tensor object at 0x000002B4AE1E3D60>
# 128 absolute_ <built-in method absolute_ of Tensor object at 0x000002B4AE1E3D60>
# 129 acos <built-in method acos of Tensor object at 0x000002B4AE1E3D60>
# 130 acos_ <built-in method acos_ of Tensor object at 0x000002B4AE1E3D60>
# 131 acosh <built-in method acosh of Tensor object at 0x000002B4AE1E3D60>
# 132 acosh_ <built-in method acosh_ of Tensor object at 0x000002B4AE1E3D60>
# 133 add <built-in method add of Tensor object at 0x000002B4AE1E3D60>
# 134 add_ <built-in method add_ of Tensor object at 0x000002B4AE1E3D60>
# 135 addbmm <built-in method addbmm of Tensor object at 0x000002B4AE1E3D60>
# 136 addbmm_ <built-in method addbmm_ of Tensor object at 0x000002B4AE1E3D60>
# 137 addcdiv <built-in method addcdiv of Tensor object at 0x000002B4AE1E3D60>
# 138 addcdiv_ <built-in method addcdiv_ of Tensor object at 0x000002B4AE1E3D60>
# 139 addcmul <built-in method addcmul of Tensor object at 0x000002B4AE1E3D60>
# 140 addcmul_ <built-in method addcmul_ of Tensor object at 0x000002B4AE1E3D60>
# 141 addmm <built-in method addmm of Tensor object at 0x000002B4AE1E3D60>
# 142 addmm_ <built-in method addmm_ of Tensor object at 0x000002B4AE1E3D60>
# 143 addmv <built-in method addmv of Tensor object at 0x000002B4AE1E3D60>
# 144 addmv_ <built-in method addmv_ of Tensor object at 0x000002B4AE1E3D60>
# 145 addr <built-in method addr of Tensor object at 0x000002B4AE1E3D60>
# 146 addr_ <built-in method addr_ of Tensor object at 0x000002B4AE1E3D60>
# 147 adjoint <built-in method adjoint of Tensor object at 0x000002B4AE1E3D60>
# 148 align_as <built-in method align_as of Tensor object at 0x000002B4AE1E3D60>
# 149 align_to <bound method Tensor.align_to of tensor([[10, 10],
#         [20, 30]])>
# 150 all <built-in method all of Tensor object at 0x000002B4AE1E3D60>
# 151 allclose <built-in method allclose of Tensor object at 0x000002B4AE1E3D60>
# 152 amax <built-in method amax of Tensor object at 0x000002B4AE1E3D60>
# 153 amin <built-in method amin of Tensor object at 0x000002B4AE1E3D60>
# 154 aminmax <built-in method aminmax of Tensor object at 0x000002B4AE1E3D60>
# 155 angle <built-in method angle of Tensor object at 0x000002B4AE1E3D60>
# 156 any <built-in method any of Tensor object at 0x000002B4AE1E3D60>
# 157 apply_ <built-in method apply_ of Tensor object at 0x000002B4AE1E3D60>
# 158 arccos <built-in method arccos of Tensor object at 0x000002B4AE1E3D60>
# 159 arccos_ <built-in method arccos_ of Tensor object at 0x000002B4AE1E3D60>
# 160 arccosh <built-in method arccosh of Tensor object at 0x000002B4AE1E3D60>
# 161 arccosh_ <built-in method arccosh_ of Tensor object at 0x000002B4AE1E3D60>
# 162 arcsin <built-in method arcsin of Tensor object at 0x000002B4AE1E3D60>
# 163 arcsin_ <built-in method arcsin_ of Tensor object at 0x000002B4AE1E3D60>
# 164 arcsinh <built-in method arcsinh of Tensor object at 0x000002B4AE1E3D60>
# 165 arcsinh_ <built-in method arcsinh_ of Tensor object at 0x000002B4AE1E3D60>
# 166 arctan <built-in method arctan of Tensor object at 0x000002B4AE1E3D60>
# 167 arctan2 <built-in method arctan2 of Tensor object at 0x000002B4AE1E3D60>
# 168 arctan2_ <built-in method arctan2_ of Tensor object at 0x000002B4AE1E3D60>
# 169 arctan_ <built-in method arctan_ of Tensor object at 0x000002B4AE1E3D60>
# 170 arctanh <built-in method arctanh of Tensor object at 0x000002B4AE1E3D60>
# 171 arctanh_ <built-in method arctanh_ of Tensor object at 0x000002B4AE1E3D60>
# 172 argmax <built-in method argmax of Tensor object at 0x000002B4AE1E3D60>
# 173 argmin <built-in method argmin of Tensor object at 0x000002B4AE1E3D60>
# 174 argsort <built-in method argsort of Tensor object at 0x000002B4AE1E3D60>
# 175 argwhere <built-in method argwhere of Tensor object at 0x000002B4AE1E3D60>
# 176 as_strided <built-in method as_strided of Tensor object at 0x000002B4AE1E3D60>
# 177 as_strided_ <built-in method as_strided_ of Tensor object at 0x000002B4AE1E3D60>
# 178 as_subclass <built-in method as_subclass of Tensor object at 0x000002B4AE1E3D60>
# 179 asin <built-in method asin of Tensor object at 0x000002B4AE1E3D60>
# 180 asin_ <built-in method asin_ of Tensor object at 0x000002B4AE1E3D60>
# 181 asinh <built-in method asinh of Tensor object at 0x000002B4AE1E3D60>
# 182 asinh_ <built-in method asinh_ of Tensor object at 0x000002B4AE1E3D60>
# 183 atan <built-in method atan of Tensor object at 0x000002B4AE1E3D60>
# 184 atan2 <built-in method atan2 of Tensor object at 0x000002B4AE1E3D60>
# 185 atan2_ <built-in method atan2_ of Tensor object at 0x000002B4AE1E3D60>
# 186 atan_ <built-in method atan_ of Tensor object at 0x000002B4AE1E3D60>
# 187 atanh <built-in method atanh of Tensor object at 0x000002B4AE1E3D60>
# 188 atanh_ <built-in method atanh_ of Tensor object at 0x000002B4AE1E3D60>
# 189 backward <bound method Tensor.backward of tensor([[10, 10],
#         [20, 30]])>
# 190 baddbmm <built-in method baddbmm of Tensor object at 0x000002B4AE1E3D60>
# 191 baddbmm_ <built-in method baddbmm_ of Tensor object at 0x000002B4AE1E3D60>
# 192 bernoulli <built-in method bernoulli of Tensor object at 0x000002B4AE1E3D60>
# 193 bernoulli_ <built-in method bernoulli_ of Tensor object at 0x000002B4AE1E3D60>
# 194 bfloat16 <built-in method bfloat16 of Tensor object at 0x000002B4AE1E3D60>
# 195 bincount <built-in method bincount of Tensor object at 0x000002B4AE1E3D60>
# 196 bitwise_and <built-in method bitwise_and of Tensor object at 0x000002B4AE1E3D60>
# 197 bitwise_and_ <built-in method bitwise_and_ of Tensor object at 0x000002B4AE1E3D60>
# 198 bitwise_left_shift <built-in method bitwise_left_shift of Tensor object at 0x000002B4AE1E3D60>
# 199 bitwise_left_shift_ <built-in method bitwise_left_shift_ of Tensor object at 0x000002B4AE1E3D60>
# 200 bitwise_not <built-in method bitwise_not of Tensor object at 0x000002B4AE1E3D60>
# 201 bitwise_not_ <built-in method bitwise_not_ of Tensor object at 0x000002B4AE1E3D60>
# 202 bitwise_or <built-in method bitwise_or of Tensor object at 0x000002B4AE1E3D60>
# 203 bitwise_or_ <built-in method bitwise_or_ of Tensor object at 0x000002B4AE1E3D60>
# 204 bitwise_right_shift <built-in method bitwise_right_shift of Tensor object at 0x000002B4AE1E3D60>
# 205 bitwise_right_shift_ <built-in method bitwise_right_shift_ of Tensor object at 0x000002B4AE1E3D60>
# 206 bitwise_xor <built-in method bitwise_xor of Tensor object at 0x000002B4AE1E3D60>
# 207 bitwise_xor_ <built-in method bitwise_xor_ of Tensor object at 0x000002B4AE1E3D60>
# 208 bmm <built-in method bmm of Tensor object at 0x000002B4AE1E3D60>
# 209 bool <built-in method bool of Tensor object at 0x000002B4AE1E3D60>
# 210 broadcast_to <built-in method broadcast_to of Tensor object at 0x000002B4AE1E3D60>
# 211 byte <built-in method byte of Tensor object at 0x000002B4AE1E3D60>
# 212 cauchy_ <built-in method cauchy_ of Tensor object at 0x000002B4AE1E3D60>
# 213 ccol_indices <built-in method ccol_indices of Tensor object at 0x000002B4AE1E3D60>
# 214 cdouble <built-in method cdouble of Tensor object at 0x000002B4AE1E3D60>
# 215 ceil <built-in method ceil of Tensor object at 0x000002B4AE1E3D60>
# 216 ceil_ <built-in method ceil_ of Tensor object at 0x000002B4AE1E3D60>
# 217 cfloat <built-in method cfloat of Tensor object at 0x000002B4AE1E3D60>
# 218 chalf <built-in method chalf of Tensor object at 0x000002B4AE1E3D60>
# 219 char <built-in method char of Tensor object at 0x000002B4AE1E3D60>
# 220 cholesky <built-in method cholesky of Tensor object at 0x000002B4AE1E3D60>
# 221 cholesky_inverse <built-in method cholesky_inverse of Tensor object at 0x000002B4AE1E3D60>
# 222 cholesky_solve <built-in method cholesky_solve of Tensor object at 0x000002B4AE1E3D60>
# 223 chunk <built-in method chunk of Tensor object at 0x000002B4AE1E3D60>
# 224 clamp <built-in method clamp of Tensor object at 0x000002B4AE1E3D60>
# 225 clamp_ <built-in method clamp_ of Tensor object at 0x000002B4AE1E3D60>
# 226 clamp_max <built-in method clamp_max of Tensor object at 0x000002B4AE1E3D60>
# 227 clamp_max_ <built-in method clamp_max_ of Tensor object at 0x000002B4AE1E3D60>
# 228 clamp_min <built-in method clamp_min of Tensor object at 0x000002B4AE1E3D60>
# 229 clamp_min_ <built-in method clamp_min_ of Tensor object at 0x000002B4AE1E3D60>
# 230 clip <built-in method clip of Tensor object at 0x000002B4AE1E3D60>
# 231 clip_ <built-in method clip_ of Tensor object at 0x000002B4AE1E3D60>
# 232 clone <built-in method clone of Tensor object at 0x000002B4AE1E3D60>
# 233 coalesce <built-in method coalesce of Tensor object at 0x000002B4AE1E3D60>
# 234 col_indices <built-in method col_indices of Tensor object at 0x000002B4AE1E3D60>
# 235 conj <built-in method conj of Tensor object at 0x000002B4AE1E3D60>
# 236 conj_physical <built-in method conj_physical of Tensor object at 0x000002B4AE1E3D60>
# 237 conj_physical_ <built-in method conj_physical_ of Tensor object at 0x000002B4AE1E3D60>
# 238 contiguous <built-in method contiguous of Tensor object at 0x000002B4AE1E3D60>
# 239 copy_ <built-in method copy_ of Tensor object at 0x000002B4AE1E3D60>
# 240 copysign <built-in method copysign of Tensor object at 0x000002B4AE1E3D60>
# 241 copysign_ <built-in method copysign_ of Tensor object at 0x000002B4AE1E3D60>
# 242 corrcoef <built-in method corrcoef of Tensor object at 0x000002B4AE1E3D60>
# 243 cos <built-in method cos of Tensor object at 0x000002B4AE1E3D60>
# 244 cos_ <built-in method cos_ of Tensor object at 0x000002B4AE1E3D60>
# 245 cosh <built-in method cosh of Tensor object at 0x000002B4AE1E3D60>
# 246 cosh_ <built-in method cosh_ of Tensor object at 0x000002B4AE1E3D60>
# 247 count_nonzero <built-in method count_nonzero of Tensor object at 0x000002B4AE1E3D60>
# 248 cov <built-in method cov of Tensor object at 0x000002B4AE1E3D60>
# 249 cpu <built-in method cpu of Tensor object at 0x000002B4AE1E3D60>
# 250 cross <built-in method cross of Tensor object at 0x000002B4AE1E3D60>
# 251 crow_indices <built-in method crow_indices of Tensor object at 0x000002B4AE1E3D60>
# 252 cuda <built-in method cuda of Tensor object at 0x000002B4AE1E3D60>
# 253 cummax <built-in method cummax of Tensor object at 0x000002B4AE1E3D60>
# 254 cummin <built-in method cummin of Tensor object at 0x000002B4AE1E3D60>
# 255 cumprod <built-in method cumprod of Tensor object at 0x000002B4AE1E3D60>
# 256 cumprod_ <built-in method cumprod_ of Tensor object at 0x000002B4AE1E3D60>
# 257 cumsum <built-in method cumsum of Tensor object at 0x000002B4AE1E3D60>
# 258 cumsum_ <built-in method cumsum_ of Tensor object at 0x000002B4AE1E3D60>
# 259 data tensor([[10, 10],
#         [20, 30]])
# 260 data_ptr <built-in method data_ptr of Tensor object at 0x000002B4AE1E3D60>
# 261 deg2rad <built-in method deg2rad of Tensor object at 0x000002B4AE1E3D60>
# 262 deg2rad_ <built-in method deg2rad_ of Tensor object at 0x000002B4AE1E3D60>
# 263 dense_dim <built-in method dense_dim of Tensor object at 0x000002B4AE1E3D60>
# 264 dequantize <built-in method dequantize of Tensor object at 0x000002B4AE1E3D60>
# 265 det <built-in method det of Tensor object at 0x000002B4AE1E3D60>
# 266 detach <built-in method detach of Tensor object at 0x000002B4AE1E3D60>
# 267 detach_ <built-in method detach_ of Tensor object at 0x000002B4AE1E3D60>
# 268 device cpu
# 269 diag <built-in method diag of Tensor object at 0x000002B4AE1E3D60>
# 270 diag_embed <built-in method diag_embed of Tensor object at 0x000002B4AE1E3D60>
# 271 diagflat <built-in method diagflat of Tensor object at 0x000002B4AE1E3D60>
# 272 diagonal <built-in method diagonal of Tensor object at 0x000002B4AE1E3D60>
# 273 diagonal_scatter <built-in method diagonal_scatter of Tensor object at 0x000002B4AE1E3D60>
# 274 diff <built-in method diff of Tensor object at 0x000002B4AE1E3D60>
# 275 digamma <built-in method digamma of Tensor object at 0x000002B4AE1E3D60>
# 276 digamma_ <built-in method digamma_ of Tensor object at 0x000002B4AE1E3D60>
# 277 dim <built-in method dim of Tensor object at 0x000002B4AE1E3D60>
# 278 dist <built-in method dist of Tensor object at 0x000002B4AE1E3D60>
# 279 div <built-in method div of Tensor object at 0x000002B4AE1E3D60>
# 280 div_ <built-in method div_ of Tensor object at 0x000002B4AE1E3D60>
# 281 divide <built-in method divide of Tensor object at 0x000002B4AE1E3D60>
# 282 divide_ <built-in method divide_ of Tensor object at 0x000002B4AE1E3D60>
# 283 dot <built-in method dot of Tensor object at 0x000002B4AE1E3D60>
# 284 double <built-in method double of Tensor object at 0x000002B4AE1E3D60>
# 285 dsplit <built-in method dsplit of Tensor object at 0x000002B4AE1E3D60>
# 286 dtype torch.int64
# 287 eig <built-in method eig of Tensor object at 0x000002B4AE1E3D60>
# 288 element_size <built-in method element_size of Tensor object at 0x000002B4AE1E3D60>
# 289 eq <built-in method eq of Tensor object at 0x000002B4AE1E3D60>
# 290 eq_ <built-in method eq_ of Tensor object at 0x000002B4AE1E3D60>
# 291 equal <built-in method equal of Tensor object at 0x000002B4AE1E3D60>
# 292 erf <built-in method erf of Tensor object at 0x000002B4AE1E3D60>
# 293 erf_ <built-in method erf_ of Tensor object at 0x000002B4AE1E3D60>
# 294 erfc <built-in method erfc of Tensor object at 0x000002B4AE1E3D60>
# 295 erfc_ <built-in method erfc_ of Tensor object at 0x000002B4AE1E3D60>
# 296 erfinv <built-in method erfinv of Tensor object at 0x000002B4AE1E3D60>
# 297 erfinv_ <built-in method erfinv_ of Tensor object at 0x000002B4AE1E3D60>
# 298 exp <built-in method exp of Tensor object at 0x000002B4AE1E3D60>
# 299 exp2 <built-in method exp2 of Tensor object at 0x000002B4AE1E3D60>
# 300 exp2_ <built-in method exp2_ of Tensor object at 0x000002B4AE1E3D60>
# 301 exp_ <built-in method exp_ of Tensor object at 0x000002B4AE1E3D60>
# 302 expand <built-in method expand of Tensor object at 0x000002B4AE1E3D60>
# 303 expand_as <built-in method expand_as of Tensor object at 0x000002B4AE1E3D60>
# 304 expm1 <built-in method expm1 of Tensor object at 0x000002B4AE1E3D60>
# 305 expm1_ <built-in method expm1_ of Tensor object at 0x000002B4AE1E3D60>
# 306 exponential_ <built-in method exponential_ of Tensor object at 0x000002B4AE1E3D60>
# 307 fill_ <built-in method fill_ of Tensor object at 0x000002B4AE1E3D60>
# 308 fill_diagonal_ <built-in method fill_diagonal_ of Tensor object at 0x000002B4AE1E3D60>
# 309 fix <built-in method fix of Tensor object at 0x000002B4AE1E3D60>
# 310 fix_ <built-in method fix_ of Tensor object at 0x000002B4AE1E3D60>
# 311 flatten <built-in method flatten of Tensor object at 0x000002B4AE1E3D60>
# 312 flip <built-in method flip of Tensor object at 0x000002B4AE1E3D60>
# 313 fliplr <built-in method fliplr of Tensor object at 0x000002B4AE1E3D60>
# 314 flipud <built-in method flipud of Tensor object at 0x000002B4AE1E3D60>
# 315 float <built-in method float of Tensor object at 0x000002B4AE1E3D60>
# 316 float_power <built-in method float_power of Tensor object at 0x000002B4AE1E3D60>
# 317 float_power_ <built-in method float_power_ of Tensor object at 0x000002B4AE1E3D60>
# 318 floor <built-in method floor of Tensor object at 0x000002B4AE1E3D60>
# 319 floor_ <built-in method floor_ of Tensor object at 0x000002B4AE1E3D60>
# 320 floor_divide <built-in method floor_divide of Tensor object at 0x000002B4AE1E3D60>
# 321 floor_divide_ <built-in method floor_divide_ of Tensor object at 0x000002B4AE1E3D60>
# 322 fmax <built-in method fmax of Tensor object at 0x000002B4AE1E3D60>
# 323 fmin <built-in method fmin of Tensor object at 0x000002B4AE1E3D60>
# 324 fmod <built-in method fmod of Tensor object at 0x000002B4AE1E3D60>
# 325 fmod_ <built-in method fmod_ of Tensor object at 0x000002B4AE1E3D60>
# 326 frac <built-in method frac of Tensor object at 0x000002B4AE1E3D60>
# 327 frac_ <built-in method frac_ of Tensor object at 0x000002B4AE1E3D60>
# 328 frexp <built-in method frexp of Tensor object at 0x000002B4AE1E3D60>
# 329 gather <built-in method gather of Tensor object at 0x000002B4AE1E3D60>
# 330 gcd <built-in method gcd of Tensor object at 0x000002B4AE1E3D60>
# 331 gcd_ <built-in method gcd_ of Tensor object at 0x000002B4AE1E3D60>
# 332 ge <built-in method ge of Tensor object at 0x000002B4AE1E3D60>
# 333 ge_ <built-in method ge_ of Tensor object at 0x000002B4AE1E3D60>
# 334 geometric_ <built-in method geometric_ of Tensor object at 0x000002B4AE1E3D60>
# 335 geqrf <built-in method geqrf of Tensor object at 0x000002B4AE1E3D60>
# 336 ger <built-in method ger of Tensor object at 0x000002B4AE1E3D60>
# 337 get_device <built-in method get_device of Tensor object at 0x000002B4AE1E3D60>
# 338 grad None
# 339 grad_fn None
# 340 greater <built-in method greater of Tensor object at 0x000002B4AE1E3D60>
# 341 greater_ <built-in method greater_ of Tensor object at 0x000002B4AE1E3D60>
# 342 greater_equal <built-in method greater_equal of Tensor object at 0x000002B4AE1E3D60>
# 343 greater_equal_ <built-in method greater_equal_ of Tensor object at 0x000002B4AE1E3D60>
# 344 gt <built-in method gt of Tensor object at 0x000002B4AE1E3D60>
# 345 gt_ <built-in method gt_ of Tensor object at 0x000002B4AE1E3D60>
# 346 half <built-in method half of Tensor object at 0x000002B4AE1E3D60>
# 347 hardshrink <built-in method hardshrink of Tensor object at 0x000002B4AE1E3D60>
# 348 has_names <built-in method has_names of Tensor object at 0x000002B4AE1E3D60>
# 349 heaviside <built-in method heaviside of Tensor object at 0x000002B4AE1E3D60>
# 350 heaviside_ <built-in method heaviside_ of Tensor object at 0x000002B4AE1E3D60>
# 351 histc <built-in method histc of Tensor object at 0x000002B4AE1E3D60>
# 352 histogram <built-in method histogram of Tensor object at 0x000002B4AE1E3D60>
# 353 hsplit <built-in method hsplit of Tensor object at 0x000002B4AE1E3D60>
# 354 hypot <built-in method hypot of Tensor object at 0x000002B4AE1E3D60>
# 355 hypot_ <built-in method hypot_ of Tensor object at 0x000002B4AE1E3D60>
# 356 i0 <built-in method i0 of Tensor object at 0x000002B4AE1E3D60>
# 357 i0_ <built-in method i0_ of Tensor object at 0x000002B4AE1E3D60>
# 358 igamma <built-in method igamma of Tensor object at 0x000002B4AE1E3D60>
# 359 igamma_ <built-in method igamma_ of Tensor object at 0x000002B4AE1E3D60>
# 360 igammac <built-in method igammac of Tensor object at 0x000002B4AE1E3D60>
# 361 igammac_ <built-in method igammac_ of Tensor object at 0x000002B4AE1E3D60>
# ERROR: 362 imag
# 363 index_add <built-in method index_add of Tensor object at 0x000002B4AE1E3D60>
# 364 index_add_ <built-in method index_add_ of Tensor object at 0x000002B4AE1E3D60>
# 365 index_copy <built-in method index_copy of Tensor object at 0x000002B4AE1E3D60>
# 366 index_copy_ <built-in method index_copy_ of Tensor object at 0x000002B4AE1E3D60>
# 367 index_fill <built-in method index_fill of Tensor object at 0x000002B4AE1E3D60>
# 368 index_fill_ <built-in method index_fill_ of Tensor object at 0x000002B4AE1E3D60>
# 369 index_put <built-in method index_put of Tensor object at 0x000002B4AE1E3D60>
# 370 index_put_ <built-in method index_put_ of Tensor object at 0x000002B4AE1E3D60>
# 371 index_reduce <built-in method index_reduce of Tensor object at 0x000002B4AE1E3D60>
# 372 index_reduce_ <built-in method index_reduce_ of Tensor object at 0x000002B4AE1E3D60>
# 373 index_select <built-in method index_select of Tensor object at 0x000002B4AE1E3D60>
# 374 indices <built-in method indices of Tensor object at 0x000002B4AE1E3D60>
# 375 inner <built-in method inner of Tensor object at 0x000002B4AE1E3D60>
# 376 int <built-in method int of Tensor object at 0x000002B4AE1E3D60>
# 377 int_repr <built-in method int_repr of Tensor object at 0x000002B4AE1E3D60>
# 378 inverse <built-in method inverse of Tensor object at 0x000002B4AE1E3D60>
# 379 ipu <built-in method ipu of Tensor object at 0x000002B4AE1E3D60>
# 380 is_coalesced <built-in method is_coalesced of Tensor object at 0x000002B4AE1E3D60>
# 381 is_complex <built-in method is_complex of Tensor object at 0x000002B4AE1E3D60>
# 382 is_conj <built-in method is_conj of Tensor object at 0x000002B4AE1E3D60>
# 383 is_contiguous <built-in method is_contiguous of Tensor object at 0x000002B4AE1E3D60>
# 384 is_cuda False
# 385 is_distributed <built-in method is_distributed of Tensor object at 0x000002B4AE1E3D60>
# 386 is_floating_point <built-in method is_floating_point of Tensor object at 0x000002B4AE1E3D60>
# 387 is_inference <built-in method is_inference of Tensor object at 0x000002B4AE1E3D60>
# 388 is_ipu False
# 389 is_leaf True
# 390 is_meta False
# 391 is_mkldnn False
# 392 is_mps False
# 393 is_neg <built-in method is_neg of Tensor object at 0x000002B4AE1E3D60>
# 394 is_nested False
# 395 is_nonzero <built-in method is_nonzero of Tensor object at 0x000002B4AE1E3D60>
# 396 is_ort False
# 397 is_pinned <built-in method is_pinned of Tensor object at 0x000002B4AE1E3D60>
# 398 is_quantized False
# 399 is_same_size <built-in method is_same_size of Tensor object at 0x000002B4AE1E3D60>
# 400 is_set_to <built-in method is_set_to of Tensor object at 0x000002B4AE1E3D60>
# 401 is_shared <bound method Tensor.is_shared of tensor([[10, 10],
#         [20, 30]])>
# 402 is_signed <built-in method is_signed of Tensor object at 0x000002B4AE1E3D60>
# 403 is_sparse False
# 404 is_sparse_csr False
# 405 is_vulkan False
# 406 is_xpu False
# 407 isclose <built-in method isclose of Tensor object at 0x000002B4AE1E3D60>
# 408 isfinite <built-in method isfinite of Tensor object at 0x000002B4AE1E3D60>
# 409 isinf <built-in method isinf of Tensor object at 0x000002B4AE1E3D60>
# 410 isnan <built-in method isnan of Tensor object at 0x000002B4AE1E3D60>
# 411 isneginf <built-in method isneginf of Tensor object at 0x000002B4AE1E3D60>
# 412 isposinf <built-in method isposinf of Tensor object at 0x000002B4AE1E3D60>
# 413 isreal <built-in method isreal of Tensor object at 0x000002B4AE1E3D60>
# 414 istft <bound method Tensor.istft of tensor([[10, 10],
#         [20, 30]])>
# 415 item <built-in method item of Tensor object at 0x000002B4AE1E3D60>
# 416 kron <built-in method kron of Tensor object at 0x000002B4AE1E3D60>
# 417 kthvalue <built-in method kthvalue of Tensor object at 0x000002B4AE1E3D60>
# 418 layout torch.strided
# 419 lcm <built-in method lcm of Tensor object at 0x000002B4AE1E3D60>
# 420 lcm_ <built-in method lcm_ of Tensor object at 0x000002B4AE1E3D60>
# 421 ldexp <built-in method ldexp of Tensor object at 0x000002B4AE1E3D60>
# 422 ldexp_ <built-in method ldexp_ of Tensor object at 0x000002B4AE1E3D60>
# 423 le <built-in method le of Tensor object at 0x000002B4AE1E3D60>
# 424 le_ <built-in method le_ of Tensor object at 0x000002B4AE1E3D60>
# 425 lerp <built-in method lerp of Tensor object at 0x000002B4AE1E3D60>
# 426 lerp_ <built-in method lerp_ of Tensor object at 0x000002B4AE1E3D60>
# 427 less <built-in method less of Tensor object at 0x000002B4AE1E3D60>
# 428 less_ <built-in method less_ of Tensor object at 0x000002B4AE1E3D60>
# 429 less_equal <built-in method less_equal of Tensor object at 0x000002B4AE1E3D60>
# 430 less_equal_ <built-in method less_equal_ of Tensor object at 0x000002B4AE1E3D60>
# 431 lgamma <built-in method lgamma of Tensor object at 0x000002B4AE1E3D60>
# 432 lgamma_ <built-in method lgamma_ of Tensor object at 0x000002B4AE1E3D60>
# 433 log <built-in method log of Tensor object at 0x000002B4AE1E3D60>
# 434 log10 <built-in method log10 of Tensor object at 0x000002B4AE1E3D60>
# 435 log10_ <built-in method log10_ of Tensor object at 0x000002B4AE1E3D60>
# 436 log1p <built-in method log1p of Tensor object at 0x000002B4AE1E3D60>
# 437 log1p_ <built-in method log1p_ of Tensor object at 0x000002B4AE1E3D60>
# 438 log2 <built-in method log2 of Tensor object at 0x000002B4AE1E3D60>
# 439 log2_ <built-in method log2_ of Tensor object at 0x000002B4AE1E3D60>
# 440 log_ <built-in method log_ of Tensor object at 0x000002B4AE1E3D60>
# 441 log_normal_ <built-in method log_normal_ of Tensor object at 0x000002B4AE1E3D60>
# 442 log_softmax <built-in method log_softmax of Tensor object at 0x000002B4AE1E3D60>
# 443 logaddexp <built-in method logaddexp of Tensor object at 0x000002B4AE1E3D60>
# 444 logaddexp2 <built-in method logaddexp2 of Tensor object at 0x000002B4AE1E3D60>
# 445 logcumsumexp <built-in method logcumsumexp of Tensor object at 0x000002B4AE1E3D60>
# 446 logdet <built-in method logdet of Tensor object at 0x000002B4AE1E3D60>
# 447 logical_and <built-in method logical_and of Tensor object at 0x000002B4AE1E3D60>
# 448 logical_and_ <built-in method logical_and_ of Tensor object at 0x000002B4AE1E3D60>
# 449 logical_not <built-in method logical_not of Tensor object at 0x000002B4AE1E3D60>
# 450 logical_not_ <built-in method logical_not_ of Tensor object at 0x000002B4AE1E3D60>
# 451 logical_or <built-in method logical_or of Tensor object at 0x000002B4AE1E3D60>
# 452 logical_or_ <built-in method logical_or_ of Tensor object at 0x000002B4AE1E3D60>
# 453 logical_xor <built-in method logical_xor of Tensor object at 0x000002B4AE1E3D60>
# 454 logical_xor_ <built-in method logical_xor_ of Tensor object at 0x000002B4AE1E3D60>
# 455 logit <built-in method logit of Tensor object at 0x000002B4AE1E3D60>
# 456 logit_ <built-in method logit_ of Tensor object at 0x000002B4AE1E3D60>
# 457 logsumexp <built-in method logsumexp of Tensor object at 0x000002B4AE1E3D60>
# 458 long <built-in method long of Tensor object at 0x000002B4AE1E3D60>
# 459 lstsq <built-in method lstsq of Tensor object at 0x000002B4AE1E3D60>
# 460 lt <built-in method lt of Tensor object at 0x000002B4AE1E3D60>
# 461 lt_ <built-in method lt_ of Tensor object at 0x000002B4AE1E3D60>
# 462 lu <bound method Tensor.lu of tensor([[10, 10],
#         [20, 30]])>
# 463 lu_solve <built-in method lu_solve of Tensor object at 0x000002B4AE1E3D60>
# 464 mH tensor([[10, 20],
#         [10, 30]])
# 465 mT tensor([[10, 20],
#         [10, 30]])
# 466 map2_ <built-in method map2_ of Tensor object at 0x000002B4AE1E3D60>
# 467 map_ <built-in method map_ of Tensor object at 0x000002B4AE1E3D60>
# 468 masked_fill <built-in method masked_fill of Tensor object at 0x000002B4AE1E3D60>
# 469 masked_fill_ <built-in method masked_fill_ of Tensor object at 0x000002B4AE1E3D60>
# 470 masked_scatter <built-in method masked_scatter of Tensor object at 0x000002B4AE1E3D60>
# 471 masked_scatter_ <built-in method masked_scatter_ of Tensor object at 0x000002B4AE1E3D60>
# 472 masked_select <built-in method masked_select of Tensor object at 0x000002B4AE1E3D60>
# 473 matmul <built-in method matmul of Tensor object at 0x000002B4AE1E3D60>
# 474 matrix_exp <built-in method matrix_exp of Tensor object at 0x000002B4AE1E3D60>
# 475 matrix_power <built-in method matrix_power of Tensor object at 0x000002B4AE1E3D60>
# 476 max <built-in method max of Tensor object at 0x000002B4AE1E3D60>
# 477 maximum <built-in method maximum of Tensor object at 0x000002B4AE1E3D60>
# 478 mean <built-in method mean of Tensor object at 0x000002B4AE1E3D60>
# 479 median <built-in method median of Tensor object at 0x000002B4AE1E3D60>
# 480 min <built-in method min of Tensor object at 0x000002B4AE1E3D60>
# 481 minimum <built-in method minimum of Tensor object at 0x000002B4AE1E3D60>
# 482 mm <built-in method mm of Tensor object at 0x000002B4AE1E3D60>
# 483 mode <built-in method mode of Tensor object at 0x000002B4AE1E3D60>
# 484 moveaxis <built-in method moveaxis of Tensor object at 0x000002B4AE1E3D60>
# 485 movedim <built-in method movedim of Tensor object at 0x000002B4AE1E3D60>
# 486 msort <built-in method msort of Tensor object at 0x000002B4AE1E3D60>
# 487 mul <built-in method mul of Tensor object at 0x000002B4AE1E3D60>
# 488 mul_ <built-in method mul_ of Tensor object at 0x000002B4AE1E3D60>
# 489 multinomial <built-in method multinomial of Tensor object at 0x000002B4AE1E3D60>
# 490 multiply <built-in method multiply of Tensor object at 0x000002B4AE1E3D60>
# 491 multiply_ <built-in method multiply_ of Tensor object at 0x000002B4AE1E3D60>
# 492 mv <built-in method mv of Tensor object at 0x000002B4AE1E3D60>
# 493 mvlgamma <built-in method mvlgamma of Tensor object at 0x000002B4AE1E3D60>
# 494 mvlgamma_ <built-in method mvlgamma_ of Tensor object at 0x000002B4AE1E3D60>
# 495 name None
# 496 names (None, None)
# 497 nan_to_num <built-in method nan_to_num of Tensor object at 0x000002B4AE1E3D60>
# 498 nan_to_num_ <built-in method nan_to_num_ of Tensor object at 0x000002B4AE1E3D60>
# 499 nanmean <built-in method nanmean of Tensor object at 0x000002B4AE1E3D60>
# 500 nanmedian <built-in method nanmedian of Tensor object at 0x000002B4AE1E3D60>
# 501 nanquantile <built-in method nanquantile of Tensor object at 0x000002B4AE1E3D60>
# 502 nansum <built-in method nansum of Tensor object at 0x000002B4AE1E3D60>
# 503 narrow <built-in method narrow of Tensor object at 0x000002B4AE1E3D60>
# 504 narrow_copy <built-in method narrow_copy of Tensor object at 0x000002B4AE1E3D60>
# 505 ndim 2
# 506 ndimension <built-in method ndimension of Tensor object at 0x000002B4AE1E3D60>
# 507 ne <built-in method ne of Tensor object at 0x000002B4AE1E3D60>
# 508 ne_ <built-in method ne_ of Tensor object at 0x000002B4AE1E3D60>
# 509 neg <built-in method neg of Tensor object at 0x000002B4AE1E3D60>
# 510 neg_ <built-in method neg_ of Tensor object at 0x000002B4AE1E3D60>
# 511 negative <built-in method negative of Tensor object at 0x000002B4AE1E3D60>
# 512 negative_ <built-in method negative_ of Tensor object at 0x000002B4AE1E3D60>
# 513 nelement <built-in method nelement of Tensor object at 0x000002B4AE1E3D60>
# 514 new <built-in method new of Tensor object at 0x000002B4AE1E3D60>
# 515 new_empty <built-in method new_empty of Tensor object at 0x000002B4AE1E3D60>
# 516 new_empty_strided <built-in method new_empty_strided of Tensor object at 0x000002B4AE1E3D60>
# 517 new_full <built-in method new_full of Tensor object at 0x000002B4AE1E3D60>
# 518 new_ones <built-in method new_ones of Tensor object at 0x000002B4AE1E3D60>
# 519 new_tensor <built-in method new_tensor of Tensor object at 0x000002B4AE1E3D60>
# 520 new_zeros <built-in method new_zeros of Tensor object at 0x000002B4AE1E3D60>
# 521 nextafter <built-in method nextafter of Tensor object at 0x000002B4AE1E3D60>
# 522 nextafter_ <built-in method nextafter_ of Tensor object at 0x000002B4AE1E3D60>
# 523 nonzero <built-in method nonzero of Tensor object at 0x000002B4AE1E3D60>
# 524 norm <bound method Tensor.norm of tensor([[10, 10],
#         [20, 30]])>
# 525 normal_ <built-in method normal_ of Tensor object at 0x000002B4AE1E3D60>
# 526 not_equal <built-in method not_equal of Tensor object at 0x000002B4AE1E3D60>
# 527 not_equal_ <built-in method not_equal_ of Tensor object at 0x000002B4AE1E3D60>
# 528 numel <built-in method numel of Tensor object at 0x000002B4AE1E3D60>
# 529 numpy <built-in method numpy of Tensor object at 0x000002B4AE1E3D60>
# 530 orgqr <built-in method orgqr of Tensor object at 0x000002B4AE1E3D60>
# 531 ormqr <built-in method ormqr of Tensor object at 0x000002B4AE1E3D60>
# 532 outer <built-in method outer of Tensor object at 0x000002B4AE1E3D60>
# 533 output_nr 0
# 534 permute <built-in method permute of Tensor object at 0x000002B4AE1E3D60>
# 535 pin_memory <built-in method pin_memory of Tensor object at 0x000002B4AE1E3D60>
# 536 pinverse <built-in method pinverse of Tensor object at 0x000002B4AE1E3D60>
# 537 polygamma <built-in method polygamma of Tensor object at 0x000002B4AE1E3D60>
# 538 polygamma_ <built-in method polygamma_ of Tensor object at 0x000002B4AE1E3D60>
# 539 positive <built-in method positive of Tensor object at 0x000002B4AE1E3D60>
# 540 pow <built-in method pow of Tensor object at 0x000002B4AE1E3D60>
# 541 pow_ <built-in method pow_ of Tensor object at 0x000002B4AE1E3D60>
# 542 prelu <built-in method prelu of Tensor object at 0x000002B4AE1E3D60>
# 543 prod <built-in method prod of Tensor object at 0x000002B4AE1E3D60>
# 544 put <built-in method put of Tensor object at 0x000002B4AE1E3D60>
# 545 put_ <built-in method put_ of Tensor object at 0x000002B4AE1E3D60>
# 546 q_per_channel_axis <built-in method q_per_channel_axis of Tensor object at 0x000002B4AE1E3D60>
# 547 q_per_channel_scales <built-in method q_per_channel_scales of Tensor object at 0x000002B4AE1E3D60>
# 548 q_per_channel_zero_points <built-in method q_per_channel_zero_points of Tensor object at 0x000002B4AE1E3D60>
# 549 q_scale <built-in method q_scale of Tensor object at 0x000002B4AE1E3D60>
# 550 q_zero_point <built-in method q_zero_point of Tensor object at 0x000002B4AE1E3D60>
# 551 qr <built-in method qr of Tensor object at 0x000002B4AE1E3D60>
# 552 qscheme <built-in method qscheme of Tensor object at 0x000002B4AE1E3D60>
# 553 quantile <built-in method quantile of Tensor object at 0x000002B4AE1E3D60>
# 554 rad2deg <built-in method rad2deg of Tensor object at 0x000002B4AE1E3D60>
# 555 rad2deg_ <built-in method rad2deg_ of Tensor object at 0x000002B4AE1E3D60>
# 556 random_ <built-in method random_ of Tensor object at 0x000002B4AE1E3D60>
# 557 ravel <built-in method ravel of Tensor object at 0x000002B4AE1E3D60>
# 558 real tensor([[10, 10],
#         [20, 30]])
# 559 reciprocal <built-in method reciprocal of Tensor object at 0x000002B4AE1E3D60>
# 560 reciprocal_ <built-in method reciprocal_ of Tensor object at 0x000002B4AE1E3D60>
# 561 record_stream <built-in method record_stream of Tensor object at 0x000002B4AE1E3D60>
# 562 refine_names <bound method Tensor.refine_names of tensor([[10, 10],
#         [20, 30]])>
# 563 register_hook <bound method Tensor.register_hook of tensor([[10, 10],
#         [20, 30]])>
# 564 reinforce <bound method Tensor.reinforce of tensor([[10, 10],
#         [20, 30]])>
# 565 relu <built-in method relu of Tensor object at 0x000002B4AE1E3D60>
# 566 relu_ <built-in method relu_ of Tensor object at 0x000002B4AE1E3D60>
# 567 remainder <built-in method remainder of Tensor object at 0x000002B4AE1E3D60>
# 568 remainder_ <built-in method remainder_ of Tensor object at 0x000002B4AE1E3D60>
# 569 rename <bound method Tensor.rename of tensor([[10, 10],
#         [20, 30]])>
# 570 rename_ <bound method Tensor.rename_ of tensor([[10, 10],
#         [20, 30]])>
# 571 renorm <built-in method renorm of Tensor object at 0x000002B4AE1E3D60>
# 572 renorm_ <built-in method renorm_ of Tensor object at 0x000002B4AE1E3D60>
# 573 repeat <built-in method repeat of Tensor object at 0x000002B4AE1E3D60>
# 574 repeat_interleave <built-in method repeat_interleave of Tensor object at 0x000002B4AE1E3D60>
# 575 requires_grad False
# 576 requires_grad_ <built-in method requires_grad_ of Tensor object at 0x000002B4AE1E3D60>
# 577 reshape <built-in method reshape of Tensor object at 0x000002B4AE1E3D60>
# 578 reshape_as <built-in method reshape_as of Tensor object at 0x000002B4AE1E3D60>
# 579 resize <bound method Tensor.resize of tensor([[10, 10],
#         [20, 30]])>
# 580 resize_ <built-in method resize_ of Tensor object at 0x000002B4AE1E3D60>
# 581 resize_as <bound method Tensor.resize_as of tensor([[10, 10],
#         [20, 30]])>
# 582 resize_as_ <built-in method resize_as_ of Tensor object at 0x000002B4AE1E3D60>
# 583 resize_as_sparse_ <built-in method resize_as_sparse_ of Tensor object at 0x000002B4AE1E3D60>
# 584 resolve_conj <built-in method resolve_conj of Tensor object at 0x000002B4AE1E3D60>
# 585 resolve_neg <built-in method resolve_neg of Tensor object at 0x000002B4AE1E3D60>
# 586 retain_grad <built-in method retain_grad of Tensor object at 0x000002B4AE1E3D60>
# 587 retains_grad False
# 588 roll <built-in method roll of Tensor object at 0x000002B4AE1E3D60>
# 589 rot90 <built-in method rot90 of Tensor object at 0x000002B4AE1E3D60>
# 590 round <built-in method round of Tensor object at 0x000002B4AE1E3D60>
# 591 round_ <built-in method round_ of Tensor object at 0x000002B4AE1E3D60>
# 592 row_indices <built-in method row_indices of Tensor object at 0x000002B4AE1E3D60>
# 593 rsqrt <built-in method rsqrt of Tensor object at 0x000002B4AE1E3D60>
# 594 rsqrt_ <built-in method rsqrt_ of Tensor object at 0x000002B4AE1E3D60>
# 595 scatter <built-in method scatter of Tensor object at 0x000002B4AE1E3D60>
# 596 scatter_ <built-in method scatter_ of Tensor object at 0x000002B4AE1E3D60>
# 597 scatter_add <built-in method scatter_add of Tensor object at 0x000002B4AE1E3D60>
# 598 scatter_add_ <built-in method scatter_add_ of Tensor object at 0x000002B4AE1E3D60>
# 599 scatter_reduce <built-in method scatter_reduce of Tensor object at 0x000002B4AE1E3D60>
# 600 scatter_reduce_ <built-in method scatter_reduce_ of Tensor object at 0x000002B4AE1E3D60>
# 601 select <built-in method select of Tensor object at 0x000002B4AE1E3D60>
# 602 select_scatter <built-in method select_scatter of Tensor object at 0x000002B4AE1E3D60>
# 603 set_ <built-in method set_ of Tensor object at 0x000002B4AE1E3D60>
# 604 sgn <built-in method sgn of Tensor object at 0x000002B4AE1E3D60>
# 605 sgn_ <built-in method sgn_ of Tensor object at 0x000002B4AE1E3D60>
# 606 shape torch.Size([2, 2])
# 607 share_memory_ <bound method Tensor.share_memory_ of tensor([[10, 10],
#         [20, 30]])>
# 608 short <built-in method short of Tensor object at 0x000002B4AE1E3D60>
# 609 sigmoid <built-in method sigmoid of Tensor object at 0x000002B4AE1E3D60>
# 610 sigmoid_ <built-in method sigmoid_ of Tensor object at 0x000002B4AE1E3D60>
# 611 sign <built-in method sign of Tensor object at 0x000002B4AE1E3D60>
# 612 sign_ <built-in method sign_ of Tensor object at 0x000002B4AE1E3D60>
# 613 signbit <built-in method signbit of Tensor object at 0x000002B4AE1E3D60>
# 614 sin <built-in method sin of Tensor object at 0x000002B4AE1E3D60>
# 615 sin_ <built-in method sin_ of Tensor object at 0x000002B4AE1E3D60>
# 616 sinc <built-in method sinc of Tensor object at 0x000002B4AE1E3D60>
# 617 sinc_ <built-in method sinc_ of Tensor object at 0x000002B4AE1E3D60>
# 618 sinh <built-in method sinh of Tensor object at 0x000002B4AE1E3D60>
# 619 sinh_ <built-in method sinh_ of Tensor object at 0x000002B4AE1E3D60>
# 620 size <built-in method size of Tensor object at 0x000002B4AE1E3D60>
# 621 slice_scatter <built-in method slice_scatter of Tensor object at 0x000002B4AE1E3D60>
# 622 slogdet <built-in method slogdet of Tensor object at 0x000002B4AE1E3D60>
# 623 smm <built-in method smm of Tensor object at 0x000002B4AE1E3D60>
# 624 softmax <built-in method softmax of Tensor object at 0x000002B4AE1E3D60>
# 625 solve <bound method Tensor.solve of tensor([[10, 10],
#         [20, 30]])>
# 626 sort <built-in method sort of Tensor object at 0x000002B4AE1E3D60>
# 627 sparse_dim <built-in method sparse_dim of Tensor object at 0x000002B4AE1E3D60>
# 628 sparse_mask <built-in method sparse_mask of Tensor object at 0x000002B4AE1E3D60>
# 629 sparse_resize_ <built-in method sparse_resize_ of Tensor object at 0x000002B4AE1E3D60>
# 630 sparse_resize_and_clear_ <built-in method sparse_resize_and_clear_ of Tensor object at 0x000002B4AE1E3D60>
# 631 split <bound method Tensor.split of tensor([[10, 10],
#         [20, 30]])>
# 632 split_with_sizes <built-in method split_with_sizes of Tensor object at 0x000002B4AE1E3D60>
# 633 sqrt <built-in method sqrt of Tensor object at 0x000002B4AE1E3D60>
# 634 sqrt_ <built-in method sqrt_ of Tensor object at 0x000002B4AE1E3D60>
# 635 square <built-in method square of Tensor object at 0x000002B4AE1E3D60>
# 636 square_ <built-in method square_ of Tensor object at 0x000002B4AE1E3D60>
# 637 squeeze <built-in method squeeze of Tensor object at 0x000002B4AE1E3D60>
# 638 squeeze_ <built-in method squeeze_ of Tensor object at 0x000002B4AE1E3D60>
# 639 sspaddmm <built-in method sspaddmm of Tensor object at 0x000002B4AE1E3D60>
# 640 std <built-in method std of Tensor object at 0x000002B4AE1E3D60>
# 641 stft <bound method Tensor.stft of tensor([[10, 10],
#         [20, 30]])>
# 642 storage <bound method Tensor.storage of tensor([[10, 10],
#         [20, 30]])>
# 643 storage_offset <built-in method storage_offset of Tensor object at 0x000002B4AE1E3D60>
# 644 storage_type <bound method Tensor.storage_type of tensor([[10, 10],
#         [20, 30]])>
# 645 stride <built-in method stride of Tensor object at 0x000002B4AE1E3D60>
# 646 sub <built-in method sub of Tensor object at 0x000002B4AE1E3D60>
# 647 sub_ <built-in method sub_ of Tensor object at 0x000002B4AE1E3D60>
# 648 subtract <built-in method subtract of Tensor object at 0x000002B4AE1E3D60>
# 649 subtract_ <built-in method subtract_ of Tensor object at 0x000002B4AE1E3D60>
# 650 sum <built-in method sum of Tensor object at 0x000002B4AE1E3D60>
# 651 sum_to_size <built-in method sum_to_size of Tensor object at 0x000002B4AE1E3D60>
# 652 svd <built-in method svd of Tensor object at 0x000002B4AE1E3D60>
# 653 swapaxes <built-in method swapaxes of Tensor object at 0x000002B4AE1E3D60>
# 654 swapaxes_ <built-in method swapaxes_ of Tensor object at 0x000002B4AE1E3D60>
# 655 swapdims <built-in method swapdims of Tensor object at 0x000002B4AE1E3D60>
# 656 swapdims_ <built-in method swapdims_ of Tensor object at 0x000002B4AE1E3D60>
# 657 symeig <built-in method symeig of Tensor object at 0x000002B4AE1E3D60>
# 658 t <built-in method t of Tensor object at 0x000002B4AE1E3D60>
# 659 t_ <built-in method t_ of Tensor object at 0x000002B4AE1E3D60>
# 660 take <built-in method take of Tensor object at 0x000002B4AE1E3D60>
# 661 take_along_dim <built-in method take_along_dim of Tensor object at 0x000002B4AE1E3D60>
# 662 tan <built-in method tan of Tensor object at 0x000002B4AE1E3D60>
# 663 tan_ <built-in method tan_ of Tensor object at 0x000002B4AE1E3D60>
# 664 tanh <built-in method tanh of Tensor object at 0x000002B4AE1E3D60>
# 665 tanh_ <built-in method tanh_ of Tensor object at 0x000002B4AE1E3D60>
# 666 tensor_split <built-in method tensor_split of Tensor object at 0x000002B4AE1E3D60>
# 667 tile <built-in method tile of Tensor object at 0x000002B4AE1E3D60>
# 668 to <built-in method to of Tensor object at 0x000002B4AE1E3D60>
# 669 to_dense <built-in method to_dense of Tensor object at 0x000002B4AE1E3D60>
# 670 to_mkldnn <built-in method to_mkldnn of Tensor object at 0x000002B4AE1E3D60>
# 671 to_padded_tensor <built-in method to_padded_tensor of Tensor object at 0x000002B4AE1E3D60>
# 672 to_sparse <built-in method to_sparse of Tensor object at 0x000002B4AE1E3D60>
# 673 to_sparse_bsc <built-in method to_sparse_bsc of Tensor object at 0x000002B4AE1E3D60>
# 674 to_sparse_bsr <built-in method to_sparse_bsr of Tensor object at 0x000002B4AE1E3D60>
# 675 to_sparse_coo <bound method Tensor.to_sparse_coo of tensor([[10, 10],
#         [20, 30]])>
# 676 to_sparse_csc <built-in method to_sparse_csc of Tensor object at 0x000002B4AE1E3D60>
# 677 to_sparse_csr <built-in method to_sparse_csr of Tensor object at 0x000002B4AE1E3D60>
# 678 tolist <built-in method tolist of Tensor object at 0x000002B4AE1E3D60>
# 679 topk <built-in method topk of Tensor object at 0x000002B4AE1E3D60>
# 680 trace <built-in method trace of Tensor object at 0x000002B4AE1E3D60>
# 681 transpose <built-in method transpose of Tensor object at 0x000002B4AE1E3D60>
# 682 transpose_ <built-in method transpose_ of Tensor object at 0x000002B4AE1E3D60>
# 683 triangular_solve <built-in method triangular_solve of Tensor object at 0x000002B4AE1E3D60>
# 684 tril <built-in method tril of Tensor object at 0x000002B4AE1E3D60>
# 685 tril_ <built-in method tril_ of Tensor object at 0x000002B4AE1E3D60>
# 686 triu <built-in method triu of Tensor object at 0x000002B4AE1E3D60>
# 687 triu_ <built-in method triu_ of Tensor object at 0x000002B4AE1E3D60>
# 688 true_divide <built-in method true_divide of Tensor object at 0x000002B4AE1E3D60>
# 689 true_divide_ <built-in method true_divide_ of Tensor object at 0x000002B4AE1E3D60>
# 690 trunc <built-in method trunc of Tensor object at 0x000002B4AE1E3D60>
# 691 trunc_ <built-in method trunc_ of Tensor object at 0x000002B4AE1E3D60>
# 692 type <built-in method type of Tensor object at 0x000002B4AE1E3D60>
# 693 type_as <built-in method type_as of Tensor object at 0x000002B4AE1E3D60>
# 694 unbind <built-in method unbind of Tensor object at 0x000002B4AE1E3D60>
# 695 unflatten <bound method Tensor.unflatten of tensor([[10, 10],
#         [20, 30]])>
# 696 unfold <built-in method unfold of Tensor object at 0x000002B4AE1E3D60>
# 697 uniform_ <built-in method uniform_ of Tensor object at 0x000002B4AE1E3D60>
# 698 unique <bound method Tensor.unique of tensor([[10, 10],
#         [20, 30]])>
# 699 unique_consecutive <bound method Tensor.unique_consecutive of tensor([[10, 10],
#         [20, 30]])>
# 700 unsafe_chunk <built-in method unsafe_chunk of Tensor object at 0x000002B4AE1E3D60>
# 701 unsafe_split <built-in method unsafe_split of Tensor object at 0x000002B4AE1E3D60>
# 702 unsafe_split_with_sizes <built-in method unsafe_split_with_sizes of Tensor object at 0x000002B4AE1E3D60>
# 703 unsqueeze <built-in method unsqueeze of Tensor object at 0x000002B4AE1E3D60>
# 704 unsqueeze_ <built-in method unsqueeze_ of Tensor object at 0x000002B4AE1E3D60>
# 705 values <built-in method values of Tensor object at 0x000002B4AE1E3D60>
# 706 var <built-in method var of Tensor object at 0x000002B4AE1E3D60>
# 707 vdot <built-in method vdot of Tensor object at 0x000002B4AE1E3D60>
# 708 view <built-in method view of Tensor object at 0x000002B4AE1E3D60>
# 709 view_as <built-in method view_as of Tensor object at 0x000002B4AE1E3D60>
# 710 vsplit <built-in method vsplit of Tensor object at 0x000002B4AE1E3D60>
# 711 where <built-in method where of Tensor object at 0x000002B4AE1E3D60>
# 712 xlogy <built-in method xlogy of Tensor object at 0x000002B4AE1E3D60>
# 713 xlogy_ <built-in method xlogy_ of Tensor object at 0x000002B4AE1E3D60>
# 714 xpu <built-in method xpu of Tensor object at 0x000002B4AE1E3D60>
# 715 zero_ <built-in method zero_ of Tensor object at 0x000002B4AE1E3D60>

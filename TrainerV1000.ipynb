# %%
from Pointcloud.Modules.Manager import Manager

from pathlib import Path

# EXAMPLE_OBJ_FILE = "common-3d-test-models-master/stanford-bunny.obj"
# EXAMPLE_OBJ_FILE = "common-3d-test-models-master/fandisk.obj"
# EXAMPLE_OBJ_FILE = "common-3d-test-models-master/beetle.obj"
# EXAMPLE_OBJ_FILE = "untitled.obj"
# Out:
# c:\Users\ruben\miniconda3\envs\PCDenoiser\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: '[WinError 127] The specified procedure could not be found'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# c:\Users\ruben\miniconda3\envs\PCDenoiser\lib\site-packages\torchaudio\backend\utils.py:62: UserWarning: No audio backend is available.
#   warnings.warn("No audio backend is available.")

# %%
manager = Manager()
# Out:
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs

# %%
manager.train()
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | layer0    | EdgeConv   | 1.2 K
# 1 | layer1    | EdgeConv   | 16.6 K
# 2 | layer2    | EdgeConv   | 66.0 K
# 3 | layer3    | Sequential | 230 K
# 4 | layer4    | Sequential | 262 K
# 5 | layer5    | Sequential | 16.6 K
# 6 | lastLayer | Linear     | 195
# -----------------------------------------
# 593 K     Trainable params
# 0         Non-trainable params
# 593 K     Total params
# 2.376     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# 1:
# 0.33670759201049805
# 2:
# 0.3452061116695404
# 3:
# 0.3452061116695404
# 4:
# 0.33670759201049805
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 manager.train()
#
# File c:\Users\ruben\Documents\TUDelft\IN5000FinalProject\GCN-Pointcloud-Denoiser\Pointcloud\Modules\Manager.py:70, in Manager.train(self, from_checkpoint)
#      68 def train(self, from_checkpoint: str=None):
#      69     self.assertCheckpointFile(from_checkpoint)
# ---> 70     self.trainer.fit(self.model, self.train_dl, self.val_dl, ckpt_path=from_checkpoint)
#
# File c:\Users\ruben\miniconda3\envs\PCDenoiser\lib\site-packages\pytorch_lightning\trainer\trainer.py:544, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     542 self.state.status = TrainerStatus.RUNNING
#     543 self.training = True
# --> 544 call._call_and_handle_interrupt(
#     545     self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     546 )
#
# File c:\Users\ruben\miniconda3\envs\PCDenoiser\lib\site-packages\pytorch_lightning\trainer\call.py:44, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      42     if trainer.strategy.launcher is not None:
#      43         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 44     return trainer_fn(*args, **kwargs)
#      46 except _TunerExitException:
#      47     _call_teardown_hook(trainer)
#
# File c:\Users\ruben\miniconda3\envs\PCDenoiser\lib\site-packages\pytorch_lightning\trainer\trainer.py:580, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     573 assert self.state.fn is not None
#     574 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     575     self.state.fn,
#     576     ckpt_path,
#     577     model_provided=True,
#     578     model_connected=self.lightning_module is not None,
#     579 )
# --> 580 self._run(model, ckpt_path=ckpt_path)
#     582 assert self.state.stopped
#     583 self.training = False
#
# File c:\Users\ruben\miniconda3\envs\PCDenoiser\lib\site-packages\pytorch_lightning\trainer\trainer.py:989, in Trainer._run(self, model, ckpt_path)
#     984 self._signal_connector.register_signal_handlers()
#     986 # ----------------------------
#     987 # RUN THE TRAINER
#     988 # ----------------------------
# --> 989 results = self._run_stage()
#     991 # ----------------------------
#     992 # POST-Training CLEAN UP
#     993 # ----------------------------
#     994 log.debug(f"{self.__class__.__name__}: trainer tearing down")
#
# File c:\Users\ruben\miniconda3\envs\PCDenoiser\lib\site-packages\pytorch_lightning\trainer\trainer.py:1033, in Trainer._run_stage(self)
#    1031 if self.training:
#    1032     with isolate_rng():
# -> 1033         self._run_sanity_check()
#    1034     with torch.autograd.set_detect_anomaly(self._detect_anomaly):
#    1035         self.fit_loop.run()
#
# File c:\Users\ruben\miniconda3\envs\PCDenoiser\lib\site-packages\pytorch_lightning\trainer\trainer.py:1062, in Trainer._run_sanity_check(self)
#    1059 call._call_callback_hooks(self, "on_sanity_check_start")
#    1061 # run eval step
# -> 1062 val_loop.run()
#    1064 call._call_callback_hooks(self, "on_sanity_check_end")
#    1066 # reset logger connector
#
# File c:\Users\ruben\miniconda3\envs\PCDenoiser\lib\site-packages\pytorch_lightning\loops\utilities.py:182, in _no_grad_context.<locals>._decorator(self, *args, **kwargs)
#     180     context_manager = torch.no_grad
#     181 with context_manager():
# --> 182     return loop_run(self, *args, **kwargs)
#
# File c:\Users\ruben\miniconda3\envs\PCDenoiser\lib\site-packages\pytorch_lightning\loops\evaluation_loop.py:134, in _EvaluationLoop.run(self)
#     132     self.batch_progress.is_last_batch = data_fetcher.done
#     133     # run step hooks
# --> 134     self._evaluation_step(batch, batch_idx, dataloader_idx, dataloader_iter)
#     135 except StopIteration:
#     136     # this needs to wrap the `*_step` call too (not just `next`) for `dataloader_iter` support
#     137     break
#
# File c:\Users\ruben\miniconda3\envs\PCDenoiser\lib\site-packages\pytorch_lightning\loops\evaluation_loop.py:391, in _EvaluationLoop._evaluation_step(self, batch, batch_idx, dataloader_idx, dataloader_iter)
#     385 hook_name = "test_step" if trainer.testing else "validation_step"
#     386 step_args = (
#     387     self._build_step_args_from_hook_kwargs(hook_kwargs, hook_name)
#     388     if not using_dataloader_iter
#     389     else (dataloader_iter,)
#     390 )
# --> 391 output = call._call_strategy_hook(trainer, hook_name, *step_args)
#     393 self.batch_progress.increment_processed()
#     395 if using_dataloader_iter:
#     396     # update the hook kwargs now that the step method might have consumed the iterator
#
# File c:\Users\ruben\miniconda3\envs\PCDenoiser\lib\site-packages\pytorch_lightning\trainer\call.py:309, in _call_strategy_hook(trainer, hook_name, *args, **kwargs)
#     306     return None
#     308 with trainer.profiler.profile(f"[Strategy]{trainer.strategy.__class__.__name__}.{hook_name}"):
# --> 309     output = fn(*args, **kwargs)
#     311 # restore current_fx when nested context
#     312 pl_module._current_fx_name = prev_fx_name
#
# File c:\Users\ruben\miniconda3\envs\PCDenoiser\lib\site-packages\pytorch_lightning\strategies\strategy.py:403, in Strategy.validation_step(self, *args, **kwargs)
#     401 if self.model != self.lightning_module:
#     402     return self._forward_redirection(self.model, self.lightning_module, "validation_step", *args, **kwargs)
# --> 403 return self.lightning_module.validation_step(*args, **kwargs)
#
# File c:\Users\ruben\Documents\TUDelft\IN5000FinalProject\GCN-Pointcloud-Denoiser\Pointcloud\Modules\Model.py:193, in Patch2NormalModel.validation_step(self, batch, batch_idx)
#     192 def validation_step(self, batch, batch_idx):
# --> 193     val_loss, cos_loss, c_val_loss, normals, y = self._common_step(batch, batch_idx)
#     194     batch_size = len(batch)
#     195     # self.log("val_val_loss", val_loss, batch_size=batch_size)
#     196     # self.log("val_cos_loss", cos_loss, batch_size=batch_size)
#
# File c:\Users\ruben\Documents\TUDelft\IN5000FinalProject\GCN-Pointcloud-Denoiser\Pointcloud\Modules\Model.py:236, in Patch2NormalModel._common_step(self, batch, batch_idx)
#     234 val_loss = torch_val_loss(normals, _y)
#     235 cos_loss = torch_cos_loss(normals, _y, torch_ones((_y.size(0),), device=_y.device))
# --> 236 c_val_loss = custom_val_loss(normals, _y)
#     237 return val_loss, cos_loss, c_val_loss, normals, _y
#
# File c:\Users\ruben\Documents\TUDelft\IN5000FinalProject\GCN-Pointcloud-Denoiser\Pointcloud\Modules\Model.py:43, in custom_val_loss(input, target)
#      41 loss4 = torch_val_loss(input, -target)
#      42 print(f"1:\n{loss1}\n2:\n{loss2}\n3:\n{loss3}\n4:\n{loss4}")
# ---> 43 raise ValueError("STOP HERE")
#      44 return torch_cat([loss1, loss2], dim=1).min(dim=1).values.mean(dim=0)
#
# ValueError: STOP HERE

# %%
manager.validate()
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#      Validate metric           DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#       val_cos_loss           1.026534080505371
#    val_custom_val_loss      0.7041963934898376
#       val_val_loss          0.5534806251525879
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# VALIDATE Profiler Report
# Profile stats for: records
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                           ProfilerStep*         8.69%      49.933ms        99.87%     574.132ms      28.707ms      44.168ms         7.68%     574.428ms      28.721ms            20
# [pl][profile][Strategy]SingleDeviceStrategy.validati...        11.05%      63.537ms        68.45%     393.516ms      19.676ms      51.584ms         8.97%     393.730ms      19.686ms            20
#                                            aten::linear         2.16%      12.408ms        13.85%      79.641ms     284.432us       7.181ms         1.25%      85.983ms     307.082us           280
#                 [pl][profile][_EvaluationLoop].val_next         0.84%       4.808ms        10.66%      61.297ms       3.065ms       4.277ms         0.74%      61.591ms       3.080ms            20
#                             aten::cosine_embedding_loss         1.88%      10.836ms         9.98%      57.362ms       1.434ms       9.845ms         1.71%      58.036ms       1.451ms            40
# enumerate(DataLoader)#_MultiProcessingDataLoaderIter...         9.41%      54.102ms         9.63%      55.384ms       2.769ms      45.055ms         7.83%      55.847ms       2.792ms            20
# [pl][module]torch_geometric.nn.conv.edge_conv.EdgeCo...         1.78%      10.234ms         9.19%      52.826ms       2.641ms       7.729ms         1.34%      53.872ms       2.694ms            20
# [pl][module]torch_geometric.nn.conv.edge_conv.EdgeCo...         1.59%       9.128ms         8.27%      47.563ms       2.378ms       5.276ms         0.92%      49.404ms       2.470ms            20
#                                             aten::zeros         6.60%      37.969ms         7.33%      42.149ms      39.763us      25.723ms         4.47%      46.757ms      44.110us          1060
# [pl][module]torch_geometric.nn.conv.edge_conv.EdgeCo...         1.40%       8.027ms         7.25%      41.676ms       2.084ms       3.206ms         0.56%      47.063ms       2.353ms            20
#                                                aten::to         1.37%       7.885ms         6.63%      38.094ms      59.522us      10.009ms         1.74%      44.358ms      69.309us           640
#                                          aten::_to_copy         2.66%      15.317ms         5.25%      30.209ms      79.497us      11.607ms         2.02%      34.349ms      90.392us           380
# [pl][profile][Strategy]SingleDeviceStrategy.batch_to...         0.89%       5.098ms         5.07%      29.139ms       1.457ms       4.324ms         0.75%      29.288ms       1.464ms            20
#                                        aten::batch_norm         0.40%       2.320ms         4.87%      27.996ms     233.300us       1.569ms         0.27%      28.589ms     238.242us           120
# [pl][module]torch.nn.modules.container.Sequential: l...         0.91%       5.230ms         4.63%      26.644ms       1.332ms       4.133ms         0.72%      26.774ms       1.339ms            20
# [pl][module]torch.nn.modules.container.Sequential: l...         0.88%       5.041ms         4.51%      25.900ms       1.295ms       3.404ms         0.59%      21.929ms       1.096ms            20
# [pl][module]torch.nn.modules.container.Sequential: l...         0.87%       5.013ms         4.49%      25.806ms       1.290ms       3.758ms         0.65%      26.096ms       1.305ms            20
#                            aten::_batch_norm_impl_index         0.76%       4.352ms         4.47%      25.676ms     213.967us       2.419ms         0.42%      27.020ms     225.167us           120
# [pl][module]torch.nn.modules.container.Sequential: l...         0.90%       5.181ms         4.39%      25.222ms       1.261ms       4.853ms         0.84%      25.633ms       1.282ms            20
# [pl][module]torch.nn.modules.container.Sequential: l...         0.89%       5.094ms         4.00%      22.986ms       1.149ms       4.246ms         0.74%      22.852ms       1.143ms            20
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 574.884ms
# Self CUDA time total: 575.203ms

# %%
manager.test(from_checkpoint=str(Path(manager.trainer.logger.log_dir) / "checkpoints/sample-mnist-epoch27-val_val_loss0.08.ckpt"))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 manager.test(from_checkpoint=str(Path(manager.trainer.logger.log_dir) / "checkpoints/sample-mnist-epoch27-val_val_loss0.08.ckpt"))
#
# File c:\Users\ruben\Documents\TUDelft\IN5000FinalProject\GCN-Pointcloud-Denoiser\Pointcloud\Modules\Manager.py:77, in Manager.test(self, from_checkpoint)
#      76 def test(self, from_checkpoint: str=None):
# ---> 77     self.assertCheckpointFile(from_checkpoint)
#      78     self.trainer.test(self.model, self.test_dl, ckpt_path=from_checkpoint)
#
# File c:\Users\ruben\Documents\TUDelft\IN5000FinalProject\GCN-Pointcloud-Denoiser\Pointcloud\Modules\Manager.py:66, in Manager.assertCheckpointFile(self, checkpoint)
#      64 if checkpoint is not None:
#      65     path = Path(checkpoint)
# ---> 66     assert path.exists() and path.suffix == ".ckpt", f"Exists: {path.exists()}\nsuffix: {path.suffix}\nFull path: {str(path)}"
#
# AssertionError: Exists: False
# suffix: .ckpt
# Full path: tb_logs\testmodel\version_16\checkpoints\sample-mnist-epoch27-val_val_loss0.08.ckpt

# %% [markdown]
# ## Check if checkpoints can be saved during training. Also fix that we can stop and start training from whenever we want. Custom split has already been created now.
